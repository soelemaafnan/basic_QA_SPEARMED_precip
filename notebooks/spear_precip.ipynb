# %%
"""This script checks for rogue pixels in SPEAR-MED precipitation
outputs using Dask for parallel processing. It recursively finds all
'precip.nc' files, processes each in parallel, and logs the results.
This version prints real-time updates to the terminal as files are completed."""

# Import modules
import os
import glob
import logging
import time # Import the time module
from datetime import timedelta
import netCDF4
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Dask imports
import dask
from dask.distributed import Client, progress

# Configurations
CONFIG = {
    "input_directory": "/data/2/GFDL-LARGE-ENSEMBLES/TFTEST/SPEAR_c192_o1_Hist_AllForc_IC1921_K50",
    "output_directory": "outputs",
    "log_file": "output.log",
    "variable_name": "precip",
    "time_dim": "time",
    "lat_dim": "lat",
    "lon_dim": "lon",
    "threshold": 1000.0,
    "dpi": 150,
    "cmap": "Blues",
    "figure_size": (12, 8),
}

# The plotting function remains the same
def create_alert_plot(data: np.ndarray, lons: np.ndarray, lats: np.ndarray, date: object, filepath: str, t_index: int) -> None:
    """Generates and saves a plot for a specific timestep when a high value is detected."""
    try:
        precip_total_mm = data * 21600
        fig = plt.figure(figsize=CONFIG["figure_size"])
        ax = plt.axes(projection=ccrs.Robinson())
        ax.set_global()
        mesh = ax.pcolormesh(
            lons, lats, precip_total_mm, transform=ccrs.PlateCarree(), cmap=CONFIG["cmap"]
        )
        ax.coastlines()
        ax.gridlines(draw_labels=False)
        cbar = plt.colorbar(mesh, orientation='vertical', pad=0.02, aspect=30, shrink=0.8)
        cbar.set_label('Precipitation (mm/6-hr)')
        start_time = date
        end_time = start_time + timedelta(hours=6)
        basename = os.path.basename(filepath)
        title = (
            f"High Precipitation Found\n"
            f"Source: {basename} ({start_time.strftime('%Y-%m-%d %H:%M')}-{end_time.strftime('%H:%M')})"
        )
        ax.set_title(title, pad=20)
        sanitized_path = basename.replace('.nc', '')
        plot_filename = f"ALERT_{sanitized_path}_timestep_{t_index:05d}.png"
        save_path = os.path.join(CONFIG["output_directory"], plot_filename)
        plt.savefig(save_path, dpi=CONFIG["dpi"], bbox_inches='tight')
    except Exception as e:
        print(f"Error plotting {filepath} at timestep {t_index}: {e}")
    finally:
        plt.close(fig)

# "Worker" function decorated with @dask.delayed
@dask.delayed
def process_single_file(filepath: str) -> str:
    """
    Processes a single NetCDF file, prints real-time status, and returns a log message.
    """
    start_time = time.time()
    high_value_found_in_file = False
    basename = os.path.basename(filepath)
    try:
        with netCDF4.Dataset(filepath, 'r') as ds:
            precip_var = ds.variables[CONFIG["variable_name"]]
            lats = ds.variables[CONFIG["lat_dim"]][:]
            lons = ds.variables[CONFIG["lon_dim"]][:]
            time_var = ds.variables[CONFIG["time_dim"]]
            num_timesteps = len(time_var)

            for t_index in range(num_timesteps):
                data_slice = precip_var[t_index, :, :]
                if np.any(data_slice > CONFIG["threshold"]):
                    high_value_found_in_file = True
                    date = netCDF4.num2date(time_var[t_index], time_var.units, getattr(time_var, 'calendar', 'standard'))
                    # Print alert immediately to terminal
                    print(f"\nALERT! High value in {basename} at step {t_index}. Plotting...")
                    create_alert_plot(data_slice, lons, lats, date, filepath, t_index)

        end_time = time.time()
        duration = end_time - start_time
        
        # Print real-time feedback to the terminal as soon as a file is done
        print(f"COMPLETED: {basename} in {duration:.2f} seconds.")

        # Return the formal log message for the final log file
        if high_value_found_in_file:
            return f"{filepath} processed in {duration:.2f}s, values greater than {CONFIG['threshold']} kg/m2/s found!"
        else:
            return f"{filepath} processed in {duration:.2f}s, no value greater than {CONFIG['threshold']} kg/m2/s found"

    except Exception as e:
        end_time = time.time()
        duration = end_time - start_time
        # Print error immediately
        print(f"ERROR: Failed to process {basename} after {duration:.2f}s.")
        return f"ERROR processing {filepath} after {duration:.2f}s. Reason: {e}"

# Main orchestrator function
def main() -> None:
    """Main function to find files and orchestrate the parallel analysis."""
    os.makedirs(CONFIG["output_directory"], exist_ok=True)
    
    search_pattern = os.path.join(CONFIG["input_directory"], '**', '*precip.nc')
    file_list = glob.glob(search_pattern, recursive=True)
    
    if not file_list:
        print(f"No '*precip.nc' files found in '{CONFIG['input_directory']}' or its subdirectories. Exiting.")
        return
        
    print(f"Found {len(file_list)} files to process.")
    
    tasks = [process_single_file(fp) for fp in file_list]
    
    print("Starting Dask client and processing files in parallel...")
    results = dask.compute(*tasks)
    progress(results) # The text-based progress bar will still run here
    
    logging.basicConfig(
        filename=CONFIG["log_file"],
        level=logging.INFO,
        format='%(asctime)s - %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S',
        filemode='w'
    )
    
    print(f"\nAll processing complete. Writing results to '{CONFIG['log_file']}'...")
    for log_message in results:
        logging.info(log_message)

    print("Done.")

if __name__ == "__main__":
    client = Client()
    print(f"Dask client started. Dashboard link (if accessible): {client.dashboard_link}")
    
    main()
    
    client.close()
# Out:
# Dask client started. Dashboard link (if accessible): http://127.0.0.1:8787/status
# Found 270 files to process.
# Starting Dask client and processing files in parallel...
# COMPLETED: atmos_4xdaily_avg.2001010100-2010123123.precip.nc in 177.76 seconds.
# COMPLETED: atmos_4xdaily_avg.1971010100-1980123123.precip.nc in 177.77 seconds.
# COMPLETED: atmos_4xdaily_avg.1961010100-1970123123.precip.nc in 179.04 seconds.
# COMPLETED: atmos_4xdaily_avg.1951010100-1960123123.precip.nc in 179.11 seconds.
# COMPLETED: atmos_4xdaily_avg.1961010100-1970123123.precip.nc in 179.10 seconds.
# COMPLETED: atmos_4xdaily_avg.1991010100-2000123123.precip.nc in 179.93 seconds.
# COMPLETED: atmos_4xdaily_avg.1951010100-1960123123.precip.nc in 180.05 seconds.
# COMPLETED: atmos_4xdaily_avg.1951010100-1960123123.precip.nc in 180.12 seconds.
# Task exception was never retrieved
# future: <Task finished name='Task-523' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-705' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-549' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-728' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-574' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-482' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-664' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-503' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-684' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-528' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-707' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-554' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-732' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-486' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-666' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-508' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-686' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-533' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-711' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-624' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-737' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-646' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-491' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-668' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-584' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-690' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-604' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-716' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-626' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-742' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-650' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-563' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-672' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-585' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-695' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-606' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-721' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-630' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-541' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-565' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-676' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-587' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-699' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-610' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-519' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-634' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-543' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-658' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-568' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-749' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-591' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-499' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-614' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-521' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-638' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-547' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-727' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-572' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-481' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-595' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-501' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-618' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-526' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-706' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-552' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-730' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-577' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-484' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-665' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-506' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-685' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-531' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-709' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-557' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-735' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-645' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-489' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-667' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-511' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-688' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-536' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-714' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-625' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-740' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-648' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-494' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-670' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-515' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-693' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-605' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-719' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-628' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-745' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-652' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-564' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-674' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-586' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-697' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-608' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-723' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-632' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-542' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-656' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-567' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-678' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-589' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-701' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-612' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-520' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-660' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-570' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# ...
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-598' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-505' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-621' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-530' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-643' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-556' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-734' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-580' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-488' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-601' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-510' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-623' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-535' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-713' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-560' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-739' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-582' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-493' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-603' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-514' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-692' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-539' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-718' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-562' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-744' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-583' coro=<Client._gather.<locals>.wait() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py:2384> exception=AllExit()>
# Traceback (most recent call last):
#   File "/nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/client.py", line 2393, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2025-10-16 17:26:30,498 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f53c00b9-f013-49db-be48-5cce3fd4fabc')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,498 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f1a06b55-15bf-4f13-81c2-3f80e77b713c')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,505 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f7519bc2-304a-4870-ae34-1c70205c682c')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,506 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f387c9ab-3d7d-47d3-87cb-46836d252cf0')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,509 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f640a539-fbd0-4028-a0b4-a28b12ffc3e8')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,509 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f15ed6c4-03ad-4b65-ac80-f8df40e7059a')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,529 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f243b5d2-cab1-4bc2-b3ff-b2987c5db36f')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-10-16 17:26:30,529 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('process_single_file-f49b8af3-79c2-48e0-9a88-52f5ae12ff91')" coro=<Worker.execute() done, defined at /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 151
#     148 client = Client()
#     149 print(f"Dask client started. Dashboard link (if accessible): {client.dashboard_link}")
# --> 151 main()
#     153 client.close()
#
# Cell In[1], line 130, in main()
#     127 tasks = [process_single_file(fp) for fp in file_list]
#     129 print("Starting Dask client and processing files in parallel...")
# --> 130 results = dask.compute(*tasks)
#     131 progress(results) # The text-based progress bar will still run here
#     133 logging.basicConfig(
#     134     filename=CONFIG["log_file"],
#     135     level=logging.INFO,
#    (...)    138     filemode='w'
#     139 )
#
# File /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/site-packages/dask/base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /nbhome/Soelem.Bhuiyan/gfdl/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2025-10-16 17:26:49,875 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-10-16 17:26:49,877 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-10-16 17:26:49,881 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-10-16 17:26:49,882 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
